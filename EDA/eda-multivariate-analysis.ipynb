# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Real Estate Capstone Project\Datasets\gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat    shree vardhman flora   sector 90   0.70          5177.0
# 1         house             independent   sector 69   0.80         10484.0
# 2          flat  experion the heartsong  sector 108   0.98         13343.0
# 3          flat            pioneer park   sector 61   1.60         11594.0
# 4          flat          pivotal devaan   sector 84   0.41          7032.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1352.0                    Carpet area: 1352 (125.6 sq.m.)      2.0
# 1   763.0                   Built Up area: 763 (70.89 sq.m.)      1.0
# 2   734.0  Super Built up area 1283(119.19 sq.m.)Built Up...      2.0
# 3  1380.0                   Carpet area: 1380 (128.21 sq.m.)      2.0
# 4   583.0  Super Built up area 583(54.16 sq.m.)Built Up a...      2.0
#
#    bathroom balcony  floorNum facing   agePossession  super_built_up_area  \
# 0       3.0       2       7.0  North  Relatively New                  NaN
# 1       1.0       0       1.0    NaN       Undefined                  NaN
# 2       3.0       3       4.0   East  Relatively New              1282.95
# 3       2.0       2      21.0    NaN  Relatively New                  NaN
# 4       2.0       2      10.0   East    New Property               582.97
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN      1351.95           1             0           0
# 1         763.05          NaN           0             0           0
# 2         978.23       734.43           1             0           0
# 3            NaN      1380.04           0             1           0
# 4         565.00       483.00           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1            49
# 1           0       0                0             0
# 2           0       0                0           135
# 3           0       0                0           105
# 4           0       0                1            23

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 90           house                   ardee city  sector 52   5.50
# 106          house           vipul tatvam villa  sector 48   7.25
# 123          house         eros rosewood villas  sector 49   2.75
# 282          house                    rk excelo  sector 12   0.60
# 296          house                dlf the grove  sector 54   5.70
# 344          house                  independent  sector 23   2.80
# 610          house                  independent  sector 28   4.50
# 748          house                  independent  sector 57   8.00
# 803          house                  independent  sector 38   8.00
# 903          house                        ansal  sector 43   1.85
# 1003         house       dlf city plots phase 2  sector 25  10.50
# 1108          flat           ambience caitriona  sector 24  14.00
# 1224         house                  independent  sector 12   6.00
# 1314         house     unitech uniworld resorts  sector 33  10.00
# 1376         house                  independent  sector 17   3.50
# 1409         house          huda plot sector 38  sector 38   4.30
# 1580         house                  independent  sector 54   3.75
# 1649         house  unitech nirvana birch court  sector 50   7.10
# 1778         house                  independent  sector 24  10.00
# 1791         house       emaar the palm springs  sector 54  24.00
# 1796         house               uppal southend  sector 49   6.75
# 2100         house                  independent  sector 12   3.50
# 2654         house            vatika india next  sector 82   7.00
# 2976         house     unitech uniworld resorts  sector 33   9.50
# 3165         house                  independent   sector 4   0.60
# 3394         house                  independent  sector 55   1.45
# 3534         house         bhim nagar, sector 6   sector 6   0.85
# 3588         house       dlf city plots phase 2  sector 25  10.00
# 3648         house       unitech deerwood chase  sector 50   8.45
#
#       price_per_sqft   area  \
# 90          183333.0  300.0
# 106         201388.0  360.0
# 123         178571.0  154.0
# 282         120000.0   50.0
# 296         211111.0  270.0
# 344         161849.0  173.0
# 610         125000.0  360.0
# 748         266666.0  300.0
# 803         230547.0  347.0
# 903         308333.0   60.0
# 1003        261194.0  402.0
# 1108        200000.0  700.0
# 1224        315789.0  190.0
# 1314        181818.0  550.0
# 1376        218750.0  160.0
# 1409        245398.0  175.0
# 1580        234375.0  160.0
# 1649        283333.0  251.0
# 1778        229885.0  435.0
# 1791        600000.0  400.0
# 1796        290948.0  232.0
# 2100        133079.0  263.0
# 2654        194444.0  360.0
# 2976        173992.0  546.0
# 3165        105263.0   57.0
# 3394        241666.0   60.0
# 3534        126865.0   67.0
# 3588        400000.0  250.0
# 3648        235376.0  359.0
#
#                                            areaWithType  super_built_up_area  \
# 90                           Plot area 300(27.87 sq.m.)                  NaN
# 106                          Plot area 360(33.45 sq.m.)                  NaN
# 123   Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 282   Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 296                    Built Up area: 270 (25.08 sq.m.)                  NaN
# 344   Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 610                    Built Up area: 360 (33.45 sq.m.)                  NaN
# 748                          Plot area 300(27.87 sq.m.)                  NaN
# 803   Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 903                            Plot area 60(5.57 sq.m.)                  NaN
# 1003                         Plot area 402(37.35 sq.m.)                  NaN
# 1108                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 1224  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 1314                          Plot area 550(51.1 sq.m.)                  NaN
# 1376                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 1409  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 1580                         Plot area 160(14.86 sq.m.)                  NaN
# 1649                          Plot area 240(22.3 sq.m.)                  NaN
# 1778                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 1791                         Plot area 400(37.16 sq.m.)                  NaN
# 1796                         Plot area 232(21.55 sq.m.)                  NaN
# 2100  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2654  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 2976                         Plot area 546(50.73 sq.m.)                  NaN
# 3165                            Plot area 57(5.3 sq.m.)                  NaN
# 3394                           Plot area 60(5.57 sq.m.)                  NaN
# 3534                           Plot area 67(6.22 sq.m.)                  NaN
# 3588                         Plot area 250(23.23 sq.m.)                  NaN
# 3648                         Plot area 359(33.35 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 90           300.00          NaN
# 106          360.00          NaN
# 123             NaN      1650.00
# 282           30.00        15.00
# 296          269.96          NaN
# 344          160.00       150.00
# 610          360.05          NaN
# 748          300.00          NaN
# 803          347.03       215.00
# 903           60.00          NaN
# 1003         402.00          NaN
# 1108         699.98          NaN
# 1224            NaN      1600.00
# 1314         550.00          NaN
# 1376         159.95          NaN
# 1409         145.00          NaN
# 1580         160.00          NaN
# 1649         240.00          NaN
# 1778            NaN       434.97
# 1791         400.00          NaN
# 1796         232.00          NaN
# 2100        4800.00      4400.00
# 2654        3900.00      3743.00
# 2976         546.00          NaN
# 3165          57.00          NaN
# 3394          60.00          NaN
# 3534          67.00          NaN
# 3588         250.00          NaN
# 3648         359.00          NaN

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat    shree vardhman flora   sector 90   0.70          5177.0
# 1         house             independent   sector 69   0.80         10484.0
# 2          flat  experion the heartsong  sector 108   0.98         13343.0
# 3          flat            pioneer park   sector 61   1.60         11594.0
# 4          flat          pivotal devaan   sector 84   0.41          7032.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1352.0                    Carpet area: 1352 (125.6 sq.m.)      2.0
# 1   763.0                   Built Up area: 763 (70.89 sq.m.)      1.0
# 2   734.0  Super Built up area 1283(119.19 sq.m.)Built Up...      2.0
# 3  1380.0                   Carpet area: 1380 (128.21 sq.m.)      2.0
# 4   583.0  Super Built up area 583(54.16 sq.m.)Built Up a...      2.0
#
#    bathroom balcony  floorNum facing   agePossession  super_built_up_area  \
# 0       3.0       2       7.0  North  Relatively New                  NaN
# 1       1.0       0       1.0    NaN       Undefined                  NaN
# 2       3.0       3       4.0   East  Relatively New              1282.95
# 3       2.0       2      21.0    NaN  Relatively New                  NaN
# 4       2.0       2      10.0   East    New Property               582.97
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN      1351.95           1             0           0
# 1         763.05          NaN           0             0           0
# 2         978.23       734.43           1             0           0
# 3            NaN      1380.04           0             1           0
# 4         565.00       483.00           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1            49
# 1           0       0                0             0
# 2           0       0                0           135
# 3           0       0                0           105
# 4           0       0                1            23

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type         society     sector  price  price_per_sqft    area  \
# 50           house    malibu towne  sector 47   8.50         53125.0  1600.0
# 75           house     independent  sector 47   6.09         33665.0  1809.0
# 101          house  uppal southend  sector 49   6.75         31915.0  2115.0
# 112          house     independent  sector 11   3.50         15555.0  2250.0
# 144          house  dlf city plots  sector 26  20.00         44265.0  4518.0
# ...            ...             ...        ...    ...             ...     ...
# 3625         house     independent  sector 56   8.00          9654.0  8287.0
# 3649         house  uppal southend  sector 49   6.75         32328.0  2088.0
# 3711         house     independent  sector 24   4.50         33333.0  1350.0
# 3727         house             nul  sector 28  12.50         51440.0  2430.0
# 3778         house     independent  sector 43   2.20          6875.0  3200.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 50                   Built Up area: 1600 (148.64 sq.m.)     12.0      12.0
# 75    Plot area 201(168.06 sq.m.)Built Up area: 180 ...     12.0      11.0
# 101                         Plot area 235(196.49 sq.m.)     12.0      12.0
# 112                  Built Up area: 2250 (209.03 sq.m.)     10.0       1.0
# 144                         Plot area 502(419.74 sq.m.)     16.0      20.0
# ...                                                 ...      ...       ...
# 3625  Plot area 362(33.63 sq.m.)Built Up area: 8286 ...     10.0      10.0
# 3649                        Plot area 232(193.98 sq.m.)     12.0      12.0
# 3711  Plot area 163(136.29 sq.m.)Built Up area: 160 ...     10.0       8.0
# 3727                        Plot area 270(225.75 sq.m.)     16.0      17.0
# 3778                       Plot area 3200(297.29 sq.m.)     12.0      12.0
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 50        3+       4.0       North    New Property                  NaN
# 75        3+       4.0        West  Moderately Old                  NaN
# 101       3+       3.0        West  Moderately Old                  NaN
# 112        0       1.0         NaN    New Property                  NaN
# 144       3+       4.0  North-East    New Property                  NaN
# ...      ...       ...         ...             ...                  ...
# 3625      3+       4.0         NaN  Relatively New                  NaN
# 3649      3+       3.0       North  Moderately Old                  NaN
# 3711      3+       4.0        East  Relatively New                  NaN
# 3727      3+       4.0       South  Relatively New                  NaN
# 3778      3+       6.0       North    New Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 50          1599.95          NaN           0             0           0
# 75           180.00        150.0           0             0           0
# 101         2115.00          NaN           0             0           0
# 112         2249.98          NaN           0             0           0
# 144         4518.00          NaN           1             1           1
# ...             ...          ...         ...           ...         ...
# 3625        8286.00          NaN           1             1           0
# 3649        2088.00          NaN           1             1           0
# 3711         160.00        150.0           0             1           1
# 3727        2430.00          NaN           1             1           0
# 3778        3200.00          NaN           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 50             0       0                1            99
# 75             1       0                2            44
# 101            0       1                0            49
# 112            0       0                0             0
# 144            1       0                1           153
# ...          ...     ...              ...           ...
# 3625           1       0                2           107
# 3649           1       1                1            49
# 3711           0       0                1            56
# 3727           1       1                2           137
# 3778           0       0                2            50
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 476          house  indiabulls centrum park  sector 103   3.25
# 1183         house              spaze privy   sector 72   3.09
# 1613         house          godrej meridien  sector 106   5.60
# 1653         house      ireo victory valley   sector 67   8.00
# 2024         house           ats tourmaline  sector 109   1.87
# 2184         house        suncity avenue 76   sector 76   0.75
# 2216         house               ninex city   sector 76   1.75
# 2727         house      satya the hermitage  sector 103   3.15
# 2979         house   vatika the seven lamps   sector 82   1.60
# 3002         house           dlf the arbour   sector 63   8.50
# 3207         house         suncity township   sector 54   2.00
# 3342         house              spaze privy   sector 72   3.10
# 3441         house              greenopolis   sector 89   0.70
# 3476         house              independent   sector 92   1.80
#
#       price_per_sqft    area  \
# 476           8125.0  4000.0
# 1183          6981.0  4426.0
# 1613         14000.0  4000.0
# 1653         22222.0  3600.0
# 2024          8697.0  2150.0
# 2184         10067.0   745.0
# 2216          6250.0  2800.0
# 2727          6702.0  4700.0
# 2979          6597.0  2425.0
# 3002         21519.0  3950.0
# 3207         30968.0   646.0
# 3342          8486.0  3653.0
# 3441          5397.0  1297.0
# 3476          7627.0  2360.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 476                        Plot area 4000(371.61 sq.m.)      4.0       3.0
# 1183  Built Up area: 3653 (339.37 sq.m.)Carpet area:...      5.0       5.0
# 1613                       Plot area 4000(371.61 sq.m.)      5.0       4.0
# 1653                        Plot area 400(334.45 sq.m.)      6.0       7.0
# 2024                 Built Up area: 2150 (199.74 sq.m.)      3.0       4.0
# 2184  Plot area 745(69.21 sq.m.)Built Up area: 745 s...      2.0       2.0
# 2216                   Carpet area: 2800 (260.13 sq.m.)      4.0       4.0
# 2727                 Built Up area: 4700 (436.64 sq.m.)      4.0       5.0
# 2979                       Plot area 2425(225.29 sq.m.)      4.0       4.0
# 3002                 Built Up area: 3950 (366.97 sq.m.)      4.0       4.0
# 3207  Plot area 60Built Up area: 60 sq.m.Carpet area...      9.0       9.0
# 3342                       Plot area 3653(339.37 sq.m.)      5.0       5.0
# 3441                  Built Up area: 1297 (120.5 sq.m.)      2.0       2.0
# 3476                 Built Up area: 2360 (219.25 sq.m.)      4.0       5.0
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 476       3+      20.0         NaN  Under Construction                  NaN
# 1183      3+      14.0        East      Relatively New                  NaN
# 1613      3+      33.0  North-East        New Property                  NaN
# 1653      3+      51.0  North-East      Moderately Old                  NaN
# 2024       0      12.0         NaN           Undefined                  NaN
# 2184       2      11.0  North-East        New Property                  NaN
# 2216       0      14.0         NaN           Undefined                  NaN
# 2727       0      12.0        East           Undefined                  NaN
# 2979      3+      16.0       North      Moderately Old                  NaN
# 3002      3+      27.0         NaN           Undefined                  NaN
# 3207       3      11.0       North      Relatively New                  NaN
# 3342      3+      21.0         NaN      Relatively New                  NaN
# 3441       2      14.0  North-East           Undefined                  NaN
# 3476       0      13.0         NaN           Undefined                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 476         4000.00          NaN           0             0           0
# 1183        3652.94      2922.00           0             1           0
# 1613        4000.00          NaN           1             1           1
# 1653        3600.00          NaN           1             1           0
# 2024        2149.98          NaN           0             0           0
# 2184         744.97          NaN           0             0           0
# 2216            NaN      2800.01           0             0           0
# 2727        4699.95          NaN           0             0           0
# 2979        2425.00          NaN           0             1           0
# 3002        3950.03          NaN           0             0           0
# 3207          60.00        59.00           0             1           0
# 3342        3653.00          NaN           0             0           0
# 3441        1297.05          NaN           0             0           0
# 3476        2359.99          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 476            0       0                0            51
# 1183           0       0                1            33
# 1613           1       0                0           151
# 1653           1       0                1            49
# 2024           0       0                0             0
# 2184           0       0                0            40
# 2216           0       0                0             0
# 2727           0       0                0            61
# 2979           0       0                0            94
# 3002           0       0                0            61
# 3207           0       0                2             7
# 3342           0       0                0             0
# 3441           0       0                0             0
# 3476           0       0                0             0

# %%
# conclusion houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat    shree vardhman flora   sector 90   0.70          5177.0
# 1         house             independent   sector 69   0.80         10484.0
# 2          flat  experion the heartsong  sector 108   0.98         13343.0
# 3          flat            pioneer park   sector 61   1.60         11594.0
# 4          flat          pivotal devaan   sector 84   0.41          7032.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1352.0                    Carpet area: 1352 (125.6 sq.m.)      2.0
# 1   763.0                   Built Up area: 763 (70.89 sq.m.)      1.0
# 2   734.0  Super Built up area 1283(119.19 sq.m.)Built Up...      2.0
# 3  1380.0                   Carpet area: 1380 (128.21 sq.m.)      2.0
# 4   583.0  Super Built up area 583(54.16 sq.m.)Built Up a...      2.0
#
#    bathroom balcony  floorNum facing   agePossession  super_built_up_area  \
# 0       3.0       2       7.0  North  Relatively New                  NaN
# 1       1.0       0       1.0    NaN       Undefined                  NaN
# 2       3.0       3       4.0   East  Relatively New              1282.95
# 3       2.0       2      21.0    NaN  Relatively New                  NaN
# 4       2.0       2      10.0   East    New Property               582.97
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN      1351.95           1             0           0
# 1         763.05          NaN           0             0           0
# 2         978.23       734.43           1             0           0
# 3            NaN      1380.04           0             1           0
# 4         565.00       483.00           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1            49
# 1           0       0                0             0
# 2           0       0                0           135
# 3           0       0                0           105
# 4           0       0                1            23

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat    shree vardhman flora   sector 90   0.70          5177.0
# 1         house             independent   sector 69   0.80         10484.0
# 2          flat  experion the heartsong  sector 108   0.98         13343.0
# 3          flat            pioneer park   sector 61   1.60         11594.0
# 4          flat          pivotal devaan   sector 84   0.41          7032.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1352.0                    Carpet area: 1352 (125.6 sq.m.)      2.0
# 1   763.0                   Built Up area: 763 (70.89 sq.m.)      1.0
# 2   734.0  Super Built up area 1283(119.19 sq.m.)Built Up...      2.0
# 3  1380.0                   Carpet area: 1380 (128.21 sq.m.)      2.0
# 4   583.0  Super Built up area 583(54.16 sq.m.)Built Up a...      2.0
#
#    bathroom balcony  floorNum facing   agePossession  super_built_up_area  \
# 0       3.0       2       7.0  North  Relatively New                  NaN
# 1       1.0       0       1.0    NaN       Undefined                  NaN
# 2       3.0       3       4.0   East  Relatively New              1282.95
# 3       2.0       2      21.0    NaN  Relatively New                  NaN
# 4       2.0       2      10.0   East    New Property               582.97
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN      1351.95           1             0           0
# 1         763.05          NaN           0             0           0
# 2         978.23       734.43           1             0           0
# 3            NaN      1380.04           0             1           0
# 4         565.00       483.00           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1            49
# 1           0       0                0             0
# 2           0       0                0           135
# 3           0       0                0           105
# 4           0       0                1            23

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat    shree vardhman flora   sector 90   0.70          5177.0
# 1         house             independent   sector 69   0.80         10484.0
# 2          flat  experion the heartsong  sector 108   0.98         13343.0
# 3          flat            pioneer park   sector 61   1.60         11594.0
# 4          flat          pivotal devaan   sector 84   0.41          7032.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1352.0                    Carpet area: 1352 (125.6 sq.m.)      2.0
# 1   763.0                   Built Up area: 763 (70.89 sq.m.)      1.0
# 2   734.0  Super Built up area 1283(119.19 sq.m.)Built Up...      2.0
# 3  1380.0                   Carpet area: 1380 (128.21 sq.m.)      2.0
# 4   583.0  Super Built up area 583(54.16 sq.m.)Built Up a...      2.0
#
#    bathroom balcony  floorNum facing   agePossession  super_built_up_area  \
# 0       3.0       2       7.0  North  Relatively New                  NaN
# 1       1.0       0       1.0    NaN       Undefined                  NaN
# 2       3.0       3       4.0   East  Relatively New              1282.95
# 3       2.0       2      21.0    NaN  Relatively New                  NaN
# 4       2.0       2      10.0   East    New Property               582.97
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN      1351.95           1             0           0
# 1         763.05          NaN           0             0           0
# 2         978.23       734.43           1             0           0
# 3            NaN      1380.04           0             1           0
# 4         565.00       483.00           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1            49
# 1           0       0                0             0
# 2           0       0                0           135
# 3           0       0                0           105
# 4           0       0                1            23

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))
filtered_df = df[df['area'] < 10000]
sns.scatterplot(x=filtered_df['area'], y=filtered_df['price'], hue=filtered_df['bedRoom'])
plt.title("Price vs Area (Area < 10,000)")
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data: area < 10000
filtered_df = df[df['area'] < 10000]

# Set the style
plt.figure(figsize=(12,8))

# Plot regression line per bedroom
bedroom_values = sorted(filtered_df['bedRoom'].dropna().unique())

# Loop through each bedroom category
for bed in bedroom_values:
    sub_df = filtered_df[filtered_df['bedRoom'] == bed]
    sns.regplot(
        x=sub_df['area'],
        y=sub_df['price'],
        scatter=True,
        label=f'{int(bed)} BHK',
        scatter_kws={'alpha': 0.6},
        line_kws={'linewidth': 2}
    )

plt.title("Price vs Area (with Regression Lines) for Area < 10000")
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.legend(title="Bedroom Count")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))

# Filter the full DataFrame FIRST
filtered_df = df[df['area'] < 10000]

# Then use columns from filtered_df
sns.scatterplot(
    x=filtered_df['area'],
    y=filtered_df['price'],
    hue=filtered_df['agePossession'],
    palette='coolwarm'  # Optional: customize colors
)

plt.title("Price vs Area (Age of Possession, Area < 10000)")
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.legend(title="Age of Possession")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))

# Filter the entire DataFrame FIRST
filtered_df = df[df['area'] < 10000]

# Now safely plot
sns.scatterplot(
    x=filtered_df['area'],
    y=filtered_df['price'],
    hue=filtered_df['furnishing_type'].astype('category'),  # safe now
    palette='Set2'  # Optional: gives nice category colors
)

plt.title("Price vs Area (by Furnishing Type, Area < 10,000)", fontsize=14)
plt.xlabel("Area (sq ft)", fontsize=12)
plt.ylabel("Price", fontsize=12)
plt.legend(title="Furnishing Type")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(
    x=df['luxury_score'],
    y=df['price']
)
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ### correlation

# %%
# Select only numeric columns explicitly to avoid issues
numeric_df = df.select_dtypes(include='number')

# Compute correlation
corr_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    corr_matrix,
    annot=True,              # Show values in cells
    fmt=".2f",               # Format floats to 2 decimal places
    cmap='coolwarm',         # Better color contrast
    square=True,             # Make cells square
    linewidths=0.5,          # Cell borders
    cbar_kws={"shrink": .75} # Smaller colorbar
)

plt.title("Correlation Heatmap", fontsize=14)
plt.tight_layout()
plt.show()

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')
numeric_df = df.select_dtypes(include='number')
correlation_with_price = numeric_df.corr()['price'].sort_values(ascending=False)
print(correlation_with_price)
# Out:
# price                  1.000000
# super_built_up_area    0.772693
# bathroom               0.589886
# bedRoom                0.522993
# servant room           0.401017
# price_per_sqft         0.391323
# pooja room             0.341550
# store room             0.309158
# study room             0.258672
# furnishing_type        0.249948
# luxury_score           0.094869
# built_up_area          0.024618
# area                   0.019634
# carpet_area           -0.003113
# others                -0.003455
# floorNum              -0.094322
# Name: price, dtype: float64

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat    shree vardhman flora   sector 90   0.70          5177.0
# 1         house             independent   sector 69   0.80         10484.0
# 2          flat  experion the heartsong  sector 108   0.98         13343.0
# 3          flat            pioneer park   sector 61   1.60         11594.0
# 4          flat          pivotal devaan   sector 84   0.41          7032.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1352.0                    Carpet area: 1352 (125.6 sq.m.)      2.0
# 1   763.0                   Built Up area: 763 (70.89 sq.m.)      1.0
# 2   734.0  Super Built up area 1283(119.19 sq.m.)Built Up...      2.0
# 3  1380.0                   Carpet area: 1380 (128.21 sq.m.)      2.0
# 4   583.0  Super Built up area 583(54.16 sq.m.)Built Up a...      2.0
#
#    bathroom balcony  floorNum facing   agePossession  super_built_up_area  \
# 0       3.0       2       7.0  North  Relatively New                  NaN
# 1       1.0       0       1.0    NaN       Undefined                  NaN
# 2       3.0       3       4.0   East  Relatively New              1282.95
# 3       2.0       2      21.0    NaN  Relatively New                  NaN
# 4       2.0       2      10.0   East    New Property               582.97
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN      1351.95           1             0           0
# 1         763.05          NaN           0             0           0
# 2         978.23       734.43           1             0           0
# 3            NaN      1380.04           0             1           0
# 4         565.00       483.00           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1            49
# 1           0       0                0             0
# 2           0       0                0           135
# 3           0       0                0           105
# 4           0       0                1            23

# %%
sns.pairplot(df)
